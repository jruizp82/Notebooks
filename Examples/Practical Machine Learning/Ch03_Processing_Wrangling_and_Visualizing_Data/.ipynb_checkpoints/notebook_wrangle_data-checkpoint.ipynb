# %% [markdown]
# # Data Wrangling
#
# This notebook presents different data wrangling techniques used commonly

# %%
# import required libraries
import random
import datetime 
import numpy as np
import pandas as pd
from random import randrange
from sklearn import preprocessing

from IPython.display import display

pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Utilities

# %%
def _random_date(start,date_count):
    """This function generates a random date based on params
    Args:
        start (date object): the base date
        date_count (int): number of dates to be generated
    Returns:
        list of random dates

    """
    current = start
    while date_count > 0:
        curr = current + datetime.timedelta(days=randrange(42))
        yield curr
        date_count-=1


def generate_sample_data(row_count=100):
    """This function generates a random transaction dataset
    Args:
        row_count (int): number of rows for the dataframe
    Returns:
        a pandas dataframe

    """
    
    # sentinels
    startDate = datetime.datetime(2016, 1, 1,13)
    serial_number_sentinel = 1000
    user_id_sentinel = 5001
    product_id_sentinel = 101
    price_sentinel = 2000
    
    
    # base list of attributes
    data_dict = {
    'Serial No': np.arange(row_count)+serial_number_sentinel,
    'Date': np.random.permutation(pd.to_datetime([x.strftime("%d-%m-%Y") 
                                                    for x in _random_date(startDate,
                                                                          row_count)]).date
                                  ),
    'User ID': np.random.permutation(np.random.randint(0,
                                                       row_count,
                                                       size=int(row_count/10)) + user_id_sentinel).tolist()*10,
    'Product ID': np.random.permutation(np.random.randint(0,
                                                          row_count,
                                                          size=int(row_count/10))+ product_id_sentinel).tolist()*10 ,
    'Quantity Purchased': np.random.permutation(np.random.randint(1,
                                                                  42,
                                                                  size=row_count)),
    'Price': np.round(np.abs(np.random.randn(row_count)+1)*price_sentinel,
                      decimals=2),
    'User Type':np.random.permutation([chr(random.randrange(97, 97 + 3 + 1)) 
                                            for i in range(row_count)])
    }
    
    # introduce missing values
    for index in range(int(np.sqrt(row_count))): 
        data_dict['Price'][np.argmax(data_dict['Price'] == random.choice(data_dict['Price']))] = np.nan
        data_dict['User Type'][np.argmax(data_dict['User Type'] == random.choice(data_dict['User Type']))] = np.nan
        data_dict['Date'][np.argmax(data_dict['Date'] == random.choice(data_dict['Date']))] = np.nan
        data_dict['Product ID'][np.argmax(data_dict['Product ID'] == random.choice(data_dict['Product ID']))] = 0
        data_dict['Serial No'][np.argmax(data_dict['Serial No'] == random.choice(data_dict['Serial No']))] = -1
        data_dict['User ID'][np.argmax(data_dict['User ID'] == random.choice(data_dict['User ID']))] = -101
        
    
    # create data frame
    df = pd.DataFrame(data_dict)
    
    return df
    

def describe_dataframe(df=pd.DataFrame()):
    """This function generates descriptive stats of a dataframe
    Args:
        df (dataframe): the dataframe to be analyzed
    Returns:
        None

    """
    print("\n\n")
    print("*"*30)
    print("About the Data")
    print("*"*30)
    
    print("Number of rows::",df.shape[0])
    print("Number of columns::",df.shape[1])
    print("\n")
    
    print("Column Names::",df.columns.values.tolist())
    print("\n")
    
    print("Column Data Types::\n",df.dtypes)
    print("\n")
    
    print("Columns with Missing Values::",df.columns[df.isnull().any()].tolist())
    print("\n")
    
    print("Number of rows with Missing Values::",len(pd.isnull(df).any(1).nonzero()[0].tolist()))
    print("\n")
    
    print("Sample Indices with missing data::",pd.isnull(df).any(1).nonzero()[0].tolist()[0:5])
    print("\n")
    
    print("General Stats::")
    print(df.info())
    print("\n")
    
    print("Summary Stats::")
    print(df.describe())
    print("\n")
    
    print("Dataframe Sample Rows::")
    display(df.head(5))
    
def cleanup_column_names(df,rename_dict={},do_inplace=True):
    """This function renames columns of a pandas dataframe
       It converts column names to snake case if rename_dict is not passed. 
    Args:
        rename_dict (dict): keys represent old column names and values point to 
                            newer ones
        do_inplace (bool): flag to update existing dataframe or return a new one
    Returns:
        pandas dataframe if do_inplace is set to False, None otherwise

    """
    if not rename_dict:
        return df.rename(columns={col: col.lower().replace(' ','_') 
                    for col in df.columns.values.tolist()}, 
                  inplace=do_inplace)
    else:
        return df.rename(columns=rename_dict,inplace=do_inplace)

def expand_user_type(u_type):
    """This function maps user types to user classes
    Args:
        u_type (str): user type value
    Returns:
        (str) user_class value

    """
    if u_type in ['a','b']:
        return 'new'
    elif u_type == 'c':
        return 'existing'
    elif u_type == 'd':
        return 'loyal_existing'
    else:
        return 'error'

# %% [markdown]
# ## Generate a Sample Dataset

# %%
df = generate_sample_data(row_count=1000)

# %% [markdown]
# ### Describe the Dataset

# %%
describe_dataframe(df)
# Out:
# ******************************
# About the Data
# ******************************
# Number of rows:: 1000
# Number of columns:: 7
#
#
# Column Names:: ['Serial No', 'Date', 'User ID', 'Product ID', 'Quantity Purchased', 'Price', 'User Type']
#
#
# Column Data Types::
#  Serial No               int32
# Date                   object
# User ID                 int64
# Product ID              int64
# Quantity Purchased      int32
# Price                 float64
# User Type              object
# dtype: object
#
#
# Columns with Missing Values:: ['Date', 'Price']
#
#
# Number of rows with Missing Values:: 61
#
#
# Sample Indices with missing data:: [1, 8, 12, 14, 15]
#
#
# General Stats::
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# Serial No             1000 non-null int32
# Date                  969 non-null object
# User ID               1000 non-null int64
# Product ID            1000 non-null int64
# Quantity Purchased    1000 non-null int32
# Price                 969 non-null float64
# User Type             1000 non-null object
# dtypes: float64(1), int32(2), int64(2), object(2)
# memory usage: 47.0+ KB
# None
#
#
# Summary Stats::
#          Serial No      User ID   Product ID  Quantity Purchased        Price
# count  1000.000000  1000.000000  1000.000000         1000.000000   969.000000
# mean   1454.718000  5513.571000   607.264000           21.028000  2317.276460
# std     383.018022   336.525369   275.483737           11.780322  1544.207611
# min      -1.000000  -101.000000     0.000000            1.000000     0.170000
# 25%    1224.750000  5289.000000   371.000000           11.000000  1071.080000
# 50%    1482.500000  5501.000000   610.000000           20.000000  2100.050000
# 75%    1743.250000  5768.000000   855.000000           31.000000  3274.340000
# max    1999.000000  5986.000000  1075.000000           41.000000  7602.200000
#
#
# Dataframe Sample Rows::
# C:\Users\RUIZ\Anaconda3\lib\site-packages\ipykernel_launcher.py:98: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
# C:\Users\RUIZ\Anaconda3\lib\site-packages\ipykernel_launcher.py:101: FutureWarning: Series.nonzero() is deprecated and will be removed in a future version.Use Series.to_numpy().nonzero() instead
#    Serial No        Date  User ID  Product ID  Quantity Purchased    Price  \
# 0       1000  2016-01-22     -101           0                  32  2492.99
# 1       1001         NaN     5986         731                  31  3855.31
# 2       1002  2016-04-01     5496         581                  10  4327.59
# 3       1003  2016-09-01     5933         382                   7   193.57
# 4       1004  2016-01-02     5072         896                   2  1182.22
#
#   User Type
# 0         n
# 1         n
# 2         n
# 3         n
# 4         n

# %% [markdown]
# ### Rename Columns

# %%
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['Serial No', 'Date', 'User ID', 'Product ID', 'Quantity Purchased', 'Price', 'User Type']

# %%
cleanup_column_names(df)

# %%
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['serial_no', 'date', 'user_id', 'product_id', 'quantity_purchased', 'price', 'user_type']

# %% [markdown]
# ### Sort Rows on defined attributes

# %%
display(df.sort_values(['serial_no', 'price'], 
                         ascending=[True, False]).head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 546         -1  2016-02-02     5501         434                  12  6038.01
# 827         -1  2016-01-01     5715         886                  22  5067.57
# 226         -1  2016-01-14     5314         585                   6  4603.01
# 634         -1  2016-06-01     5381        1014                  28  4444.33
# 139         -1         NaN     5643         612                  16  4218.84
#
#     user_type
# 546         d
# 827         b
# 226         a
# 634         d
# 139         a

# %% [markdown]
# ### Rearrange Columns in a Dataframe

# %%
display(df[['serial_no','date','user_id','user_type',
              'product_id','quantity_purchased','price']].head())
# Out:
#    serial_no        date  user_id user_type  product_id  quantity_purchased  \
# 0       1000  2016-01-22     -101         n           0                  32
# 1       1001         NaN     5986         n         731                  31
# 2       1002  2016-04-01     5496         n         581                  10
# 3       1003  2016-09-01     5933         n         382                   7
# 4       1004  2016-01-02     5072         n         896                   2
#
#      price
# 0  2492.99
# 1  3855.31
# 2  4327.59
# 3   193.57
# 4  1182.22

# %% [markdown]
# ### Filtering Columns

# %% [markdown]
# Using Column Index

# %%
# print 10 values from column at index 3
print(df.iloc[:,3].values[0:10])
# Out:
# [  0 731 581 382 896 557 586 802 838 210]

# %% [markdown]
# Using Column Name

# %%
# print 10 values of quantity purchased
print(df.quantity_purchased.values[0:10])
# Out:
# [32 31 10  7  2 15 22 21  3 25]

# %% [markdown]
# Using Column Datatype

# %%
# print 10 values of columns with data type float
print(df.select_dtypes(include=['float64']).values[:10,0])
# Out:
# [2492.99 3855.31 4327.59  193.57 1182.22   82.61 4813.28  174.94 2043.62
#  3450.43]

# %% [markdown]
# ### Filtering Rows

# %% [markdown]
# Select specific rows

# %%
display(df.iloc[[10,501,20]])
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 10        1010  2016-01-19     5196         827                  32   923.18
# 501       1501  2016-09-01     5986         731                  10  6746.58
# 20        1020  2016-03-02     5556         855                   6   748.07
#
#     user_type
# 10          n
# 501         d
# 20          d

# %% [markdown]
# Exclude Specific Row indices

# %%
display(df.drop([0,24,51], axis=0).head())
# Out:
#    serial_no        date  user_id  product_id  quantity_purchased    price  \
# 1       1001         NaN     5986         731                  31  3855.31
# 2       1002  2016-04-01     5496         581                  10  4327.59
# 3       1003  2016-09-01     5933         382                   7   193.57
# 4       1004  2016-01-02     5072         896                   2  1182.22
# 5       1005  2016-03-02     5924         557                  15    82.61
#
#   user_type
# 1         n
# 2         n
# 3         n
# 4         n
# 5         n

# %% [markdown]
# Conditional Filtering

# %%
display(df[df.quantity_purchased>25].head())
# Out:
#     serial_no        date  user_id  product_id  quantity_purchased    price  \
# 0        1000  2016-01-22     -101           0                  32  2492.99
# 1        1001         NaN     5986         731                  31  3855.31
# 10       1010  2016-01-19     5196         827                  32   923.18
# 11       1011  2016-01-29     5913         596                  29  4751.88
# 16       1016  2016-04-02     5837         639                  29  2501.69
#
#    user_type
# 0          n
# 1          n
# 10         n
# 11         n
# 16         n

# %% [markdown]
# Offset from top of the dataframe

# %%
display(df[100:].head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 100       1100  2016-09-01     5798        1056                  29   704.51
# 101       1101  2016-01-31     5986         731                   1  3888.57
# 102       1102  2016-01-13     5496         581                   6      NaN
# 103       1103         NaN     5933         382                  40  1528.01
# 104       1104  2016-11-01     5072         896                  17  2026.91
#
#     user_type
# 100         c
# 101         d
# 102         a
# 103         b
# 104         c

# %% [markdown]
# Offset from bottom of the dataframe

# %%
display(df[-10:].head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 990       1990  2016-02-02     5625         356                  41      NaN
# 991       1991  2016-01-17     5223         983                  32  2086.79
# 992       1992  2016-08-01     5930         303                  31  1469.19
# 993       1993  2016-06-01     5554         192                  10   796.03
# 994       1994  2016-01-23     5302         409                  36  2609.86
#
#     user_type
# 990         a
# 991         a
# 992         d
# 993         d
# 994         c

# %% [markdown]
# ### TypeCasting/Data Type Conversion

# %%
df['date'] = pd.to_datetime(df.date)
# compare dtypes of the original df with this one
print(df.dtypes)
# Out:
# serial_no                      int32
# date                  datetime64[ns]
# user_id                        int64
# product_id                     int64
# quantity_purchased             int32
# price                        float64
# user_type                     object
# dtype: object

# %% [markdown]
# ### Apply/Map Usage

# %% [markdown]
# Map : Create a derived attribute using map

# %%
df['user_class'] = df['user_type'].map(expand_user_type)
display(df.tail())
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 995       1995 2016-01-02     5159         452                  23  2286.66
# 996       1996 2016-01-25     5681         335                  30  3443.26
# 997       1997 2016-08-01     5942         460                  32   692.06
# 998       1998 2016-01-22     5215        1018                   3  3115.84
# 999       1999 2016-02-02     5923        1071                  23  4323.07
#
#     user_type      user_class
# 995         a             new
# 996         a             new
# 997         d  loyal_existing
# 998         a             new
# 999         c        existing

# %% [markdown]
# Apply: Using apply to get attribute ranges

# %%
display(df.select_dtypes(include=[np.number]).apply(lambda x: 
                                                        x.max()- x.min()))
# Out:
# serial_no             2000.00
# user_id               6087.00
# product_id            1075.00
# quantity_purchased      40.00
# price                 7602.03
# dtype: float64

# %% [markdown]
# Applymap: Extract week from date

# %%
df['purchase_week'] = df[['date']].applymap(lambda dt:dt.week 
                                                if not pd.isnull(dt.week) 
                                                else 0)

# %%
display(df.head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  32  2492.99
# 1       1001        NaT     5986         731                  31  3855.31
# 2       1002 2016-04-01     5496         581                  10  4327.59
# 3       1003 2016-09-01     5933         382                   7   193.57
# 4       1004 2016-01-02     5072         896                   2  1182.22
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 1         n      error              0
# 2         n      error             13
# 3         n      error             35
# 4         n      error             53

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Drop Rows with missing dates

# %%
df_dropped = df.dropna(subset=['date'])
display(df_dropped.head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  32  2492.99
# 2       1002 2016-04-01     5496         581                  10  4327.59
# 3       1003 2016-09-01     5933         382                   7   193.57
# 4       1004 2016-01-02     5072         896                   2  1182.22
# 5       1005 2016-03-02     5924         557                  15    82.61
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 2         n      error             13
# 3         n      error             35
# 4         n      error             53
# 5         n      error              9

# %% [markdown]
# Fill Missing Price values with mean price

# %%
df_dropped['price'].fillna(value=np.round(df.price.mean(),decimals=2),
                                inplace=True)

# %% [markdown]
# Fill Missing user_type values with value from previous row (forward fill)

# %%
df_dropped['user_type'].fillna(method='ffill',inplace=True)

# %% [markdown]
# Fill Missing user_type values with value from next row (backward fill)

# %%
df_dropped['user_type'].fillna(method='bfill',inplace=True)

# %% [markdown]
# ### Duplicates

# %% [markdown]
# Drop Duplicate serial_no rows

# %%
# sample duplicates
display(df_dropped[df_dropped.duplicated(subset=['serial_no'])].head())
print("Shape of df={}".format(df_dropped.shape))
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 226         -1 2016-01-14     5314         585                   6  4603.01
# 254         -1 2016-08-01     5711         939                  32  1847.84
# 259         -1 2016-01-02     5165         180                   6   576.27
# 307         -1 2016-02-01     5483         802                  20   494.53
# 349         -1 2016-01-25     5242         771                  16  3248.03
#
#     user_type user_class  purchase_week
# 226         a        new              2
# 254         c   existing             31
# 259         a        new             53
# 307         a        new              5
# 349         c   existing              4
# Shape of df=(969, 9)

# %%
df_dropped.drop_duplicates(subset=['serial_no'],inplace=True)

# %%
# updated dataframe
display(df_dropped.head())
print("Shape of df={}".format(df_dropped.shape))
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  32  2492.99
# 2       1002 2016-04-01     5496         581                  10  4327.59
# 3       1003 2016-09-01     5933         382                   7   193.57
# 4       1004 2016-01-02     5072         896                   2  1182.22
# 5       1005 2016-03-02     5924         557                  15    82.61
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 2         n      error             13
# 3         n      error             35
# 4         n      error             53
# 5         n      error              9
# Shape of df=(944, 9)

# %% [markdown]
# Remove rows which have less than 3 attributes with non-missing data

# %%
display(df.dropna(thresh=3).head())
print("Shape of df={}".format(df.dropna(thresh=3).shape))
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  32  2492.99
# 1       1001        NaT     5986         731                  31  3855.31
# 2       1002 2016-04-01     5496         581                  10  4327.59
# 3       1003 2016-09-01     5933         382                   7   193.57
# 4       1004 2016-01-02     5072         896                   2  1182.22
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 1         n      error              0
# 2         n      error             13
# 3         n      error             35
# 4         n      error             53
# Shape of df=(1000, 9)

# %% [markdown]
# ### Encode Categoricals

# %% [markdown]
# One Hot Encoding using get_dummies()

# %%
display(pd.get_dummies(df,columns=['user_type']).head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  32  2492.99
# 1       1001        NaT     5986         731                  31  3855.31
# 2       1002 2016-04-01     5496         581                  10  4327.59
# 3       1003 2016-09-01     5933         382                   7   193.57
# 4       1004 2016-01-02     5072         896                   2  1182.22
#
#   user_class  purchase_week  user_type_a  user_type_b  user_type_c  \
# 0      error              3            0            0            0
# 1      error              0            0            0            0
# 2      error             13            0            0            0
# 3      error             35            0            0            0
# 4      error             53            0            0            0
#
#    user_type_d  user_type_n
# 0            0            1
# 1            0            1
# 2            0            1
# 3            0            1
# 4            0            1

# %% [markdown]
# Label Mapping

# %%
type_map={'a':0,'b':1,'c':2,'d':3,np.NAN:-1}
df['encoded_user_type'] = df.user_type.map(type_map)
display((df.tail()))
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 995       1995 2016-01-02     5159         452                  23  2286.66
# 996       1996 2016-01-25     5681         335                  30  3443.26
# 997       1997 2016-08-01     5942         460                  32   692.06
# 998       1998 2016-01-22     5215        1018                   3  3115.84
# 999       1999 2016-02-02     5923        1071                  23  4323.07
#
#     user_type      user_class  purchase_week  encoded_user_type
# 995         a             new             53                0.0
# 996         a             new              4                0.0
# 997         d  loyal_existing             31                3.0
# 998         a             new              3                0.0
# 999         c        existing              5                2.0

# %% [markdown]
# ### Random Sampling data from DataFrame

# %%
display(df.sample(frac=0.2, replace=True, random_state=42).head())
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 102       1102 2016-01-13     5496         581                   6      NaN
# 435       1435 2016-05-01     5468         783                  10  1538.97
# 860       1860 2016-07-01     5520         239                   8   916.27
# 270       1270 2016-01-24     5768         757                  13   411.72
# 106       1106 2016-04-01     5304         586                  36  4277.24
#
#     user_type      user_class  purchase_week  encoded_user_type
# 102         a             new              2                0.0
# 435         b             new             17                1.0
# 860         c        existing             26                2.0
# 270         d  loyal_existing              3                3.0
# 106         c        existing             13                2.0

# %% [markdown]
# ### Normalizing Numeric Values

# %% [markdown]
# Normalize price values using  **Min-Max Scaler**

# %%
df_normalized = df.dropna().copy()
min_max_scaler = preprocessing.MinMaxScaler()
np_scaled = min_max_scaler.fit_transform(df_normalized['price'].values.reshape(-1,1))
df_normalized['price'] = np_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     serial_no       date  user_id  product_id  quantity_purchased     price  \
# 20       1020 2016-03-02     5556         855                   6  0.098382
# 22       1022 2016-08-02     5551         857                  31  0.409892
# 24       1024 2016-01-19     5376         823                   2  0.167797
# 27       1027 2016-01-18     5715         886                   4  0.302492
# 31       1031 2016-02-01     5757         508                  35  0.419529
#
#    user_type      user_class  purchase_week  encoded_user_type
# 20         d  loyal_existing              9                3.0
# 22         d  loyal_existing             31                3.0
# 24         d  loyal_existing              3                3.0
# 27         d  loyal_existing              3                3.0
# 31         d  loyal_existing              5                3.0

# %% [markdown]
# Normalize quantity purchased values using  **Robust Scaler**

# %%
df_normalized = df.dropna().copy()
robust_scaler = preprocessing.RobustScaler()
rs_scaled = robust_scaler.fit_transform(df_normalized['quantity_purchased'].values.reshape(-1,1))
df_normalized['quantity_purchased'] = rs_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     serial_no       date  user_id  product_id  quantity_purchased    price  \
# 20       1020 2016-03-02     5556         855               -0.75   748.07
# 22       1022 2016-08-02     5551         857                0.50  3116.18
# 24       1024 2016-01-19     5376         823               -0.95  1275.77
# 27       1027 2016-01-18     5715         886               -0.85  2299.72
# 31       1031 2016-02-01     5757         508                0.70  3189.44
#
#    user_type      user_class  purchase_week  encoded_user_type
# 20         d  loyal_existing              9                3.0
# 22         d  loyal_existing             31                3.0
# 24         d  loyal_existing              3                3.0
# 27         d  loyal_existing              3                3.0
# 31         d  loyal_existing              5                3.0

# %% [markdown]
# ### Data Summarization

# %% [markdown]
# Condition based aggregation

# %%
print("Mean price of items purchased by user_type=a :: {}".format(df['price'][df['user_type']=='a'].mean()))
# Out:
# Mean price of items purchased by user_type=a :: 2246.073909465021

# %% [markdown]
# Condtion based counts

# %%
print(df['purchase_week'].value_counts())
# Out:
# 3     179
# 4     163
# 2     102
# 53     60
# 31     56
# 39     51
# 22     51
# 26     45
# 9      43
# 44     41
# 13     39
# 5      36
# 35     34
# 0      31
# 48     27
# 17     25
# 18     17
# Name: purchase_week, dtype: int64

# %% [markdown]
# ### Group By

# %% [markdown]
# Group By certain attributes

# %%
print(df.groupby(['user_class'])['quantity_purchased'].sum())
# Out:
# user_class
# error              593
# existing          5377
# loyal_existing    5076
# new               9982
# Name: quantity_purchased, dtype: int32

# %% [markdown]
# Group By with different aggregate functions

# %%
display(df.groupby(['user_class'])['quantity_purchased'].agg([np.sum,
                                                                np.mean,
                                                                np.count_nonzero]))
# Out:
#                  sum       mean  count_nonzero
# user_class
# error            593  19.129032             31
# existing        5377  21.169291            254
# loyal_existing  5076  21.062241            241
# new             9982  21.059072            474

# %% [markdown]
# Group by specific aggregate functions for each attribute

# %%
display(df.groupby(['user_class','user_type']).agg({'price':np.mean,
                                                        'quantity_purchased':np.max}))
# Out:
#                                 price  quantity_purchased
# user_class     user_type
# error          n          2356.919655                  35
# existing       c          2272.048800                  41
# loyal_existing d          2440.875776                  41
# new            a          2246.073909                  41
#                b          2311.622698                  41

# %% [markdown]
# Group by with multiple agg for each attribute

# %%
display(df.groupby(['user_class','user_type']).agg({'price':{
                                                                'total_price':np.sum,
                                                                'mean_price':np.mean,
                                                                'variance_price':np.std,
                                                                'count':np.count_nonzero},
                                                   'quantity_purchased':np.sum}))
# Out:
# C:\Users\RUIZ\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1315: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                price                                     \
#                          total_price   mean_price variance_price  count
# user_class     user_type
# error          n            68350.67  2356.919655    1687.846267   31.0
# existing       c           568012.20  2272.048800    1545.719890  254.0
# loyal_existing d           566283.18  2440.875776    1640.632202  241.0
# new            a           545795.96  2246.073909    1494.225266  255.0
#                b           496998.88  2311.622698    1475.893534  219.0
#
#                          quantity_purchased
#                                         sum
# user_class     user_type
# error          n                        593
# existing       c                       5377
# loyal_existing d                       5076
# new            a                       5384
#                b                       4598

# %% [markdown]
# ### Pivot Tables

# %%
display(df.pivot_table(index='date', columns='user_type', 
                         values='price',aggfunc=np.mean))
# Out:
# user_type             a            b            c            d         n
# date
# 2016-01-01  2881.188333  2033.583333  2555.754615  2735.304000  1642.620
# 2016-01-02  1690.200833  4337.123333  1193.505000  2986.398000  1182.220
# 2016-01-13  2083.822500  1362.062500  2623.067143   969.160000  3450.430
# 2016-01-14  2950.387778  1397.795000  3263.040000  2800.002500       NaN
# 2016-01-15  3250.315000  2571.604000  1106.000000  2043.410000       NaN
# 2016-01-16   613.943333  1683.222500  2281.543333  2696.936000       NaN
# 2016-01-17  2710.277273  2360.113750  2705.446667  4164.300000       NaN
# 2016-01-18  2315.618571  2036.166667  2388.912000  1929.095000       NaN
# 2016-01-19  1984.092000  2539.082500  1832.945000  2453.471250  2029.205
# 2016-01-20  3616.556667  3346.604000  2926.296250  1957.798750  3129.560
# 2016-01-21  2648.433333  2668.394286  1573.961000  2070.707143       NaN
# 2016-01-22  2046.042000  1650.125000  2558.602857  1318.544000  3178.455
# 2016-01-23  1447.712857  2781.762500  2087.765714  1972.165000       NaN
# 2016-01-24  3245.583333  2072.355000  1815.457500   411.720000    37.460
# 2016-01-25  2846.518000  1831.465000  2382.525455  1740.345000       NaN
# 2016-01-26  1502.850000  2890.723333  2473.722500  1637.152857       NaN
# 2016-01-27  1315.045000  1621.146667  2359.518571  2269.085000       NaN
# 2016-01-28  1979.436667  1199.050000  3110.072000  1188.075000       NaN
# 2016-01-29  2007.301667  1788.982500  2527.673000  2427.225000  3690.260
# 2016-01-30  2575.846667  2629.540000  1812.678000  2235.808571       NaN
# 2016-01-31          NaN  2496.830000  2929.304286  2883.936667       NaN
# 2016-02-01  2035.368750  1886.898000  1478.707500  2822.593333       NaN
# 2016-02-02  3565.685000  1042.890000  3695.140000  2660.245000       NaN
# 2016-03-01  1504.400000  1565.092857          NaN  1501.350000       NaN
# 2016-03-02  3379.086667  2064.690000  1330.548333  2047.028000    82.610
# 2016-04-01  2844.630000  3225.232500  2278.255000  2220.982500  4327.590
# 2016-04-02  1865.727500  3302.540000  2105.520000  2874.494286  2501.690
# 2016-05-01  1701.260000  1635.684000  2336.302000  1316.655000       NaN
# 2016-05-02  3452.320000  1386.045000  3550.410000  3269.195000       NaN
# 2016-06-01  3354.072000  2493.542000  2405.741538  2774.620000       NaN
# 2016-06-02  1650.607143  2822.127500  1488.125000  2528.254000       NaN
# 2016-07-01  2288.088750  2566.100000  1459.228000  3082.432500       NaN
# 2016-07-02  1081.350000  3876.180000  2240.365714  3184.558750       NaN
# 2016-08-01  2095.472222  3547.728333  2627.202857  2427.327273       NaN
# 2016-08-02  2666.827500  2329.140000   957.325000  4214.101111  1386.760
# 2016-09-01  1633.815000  3838.975000  1189.960000  2478.690000   193.570
# 2016-09-02  3538.873333  2066.906000  2832.814000  2564.738000       NaN
# 2016-10-01  3123.698000  2844.297500  2407.444000  2588.644286       NaN
# 2016-10-02  1631.788750  1551.685000  1932.873750  2246.511250       NaN
# 2016-11-01  2111.712000  2972.981429  3065.192500  3631.028000  2669.920
# 2016-11-02  2199.050000  2439.926000  1505.753333  3171.930000       NaN
# 2016-12-01  1822.591667  2227.053750  2159.852222  2946.327500       NaN

# %% [markdown]
# ### Stack a Dataframe

# %%
print(df.stack())
# Out:
# 0    serial_no                            1000
#      date                  2016-01-22 00:00:00
#      user_id                              -101
#      product_id                              0
#      quantity_purchased                     32
#      price                             2492.99
#      user_type                               n
#      user_class                          error
#      purchase_week                           3
# 1    serial_no                            1001
#      user_id                              5986
#      product_id                            731
#      quantity_purchased                     31
#      price                             3855.31
#      user_type                               n
#      user_class                          error
#      purchase_week                           0
# 2    serial_no                            1002
#      date                  2016-04-01 00:00:00
#      user_id                              5496
#      product_id                            581
#      quantity_purchased                     10
#      price                             4327.59
#      user_type                               n
#      user_class                          error
#      purchase_week                          13
# 3    serial_no                            1003
#      date                  2016-09-01 00:00:00
#      user_id                              5933
#      product_id                            382
#                                   ...
# 997  serial_no                            1997
#      date                  2016-08-01 00:00:00
#      user_id                              5942
#      product_id                            460
#      quantity_purchased                     32
#      price                              692.06
#      user_type                               d
#      user_class                 loyal_existing
#      purchase_week                          31
#      encoded_user_type                       3
# 998  serial_no                            1998
#      date                  2016-01-22 00:00:00
#      user_id                              5215
#      product_id                           1018
#      quantity_purchased                      3
#      price                             3115.84
#      user_type                               a
#      user_class                            new
#      purchase_week                           3
#      encoded_user_type                       0
# 999  serial_no                            1999
#      date                  2016-02-02 00:00:00
#      user_id                              5923
#      product_id                           1071
#      quantity_purchased                     23
#      price                             4323.07
#      user_type                               c
#      user_class                       existing
#      purchase_week                           5
#      encoded_user_type                       2
# Length: 9907, dtype: object
